# %% [markdown]
# # XGBoost (Hidden) Features

# %%
import pandas as pd
import xgboost
import warnings
warnings.filterwarnings('ignore')

# %%
xgboost.__version__
# Out:
# '1.7.2'

# %%
bank = pd.read_csv('/Users/matt/Dropbox/work/courses/ms-courses/xgb-classification/bank-additional-full.csv',
                   sep=';')

# %%
bank
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
#          contact month day_of_week  ...  campaign  pdays  previous  \
# 0      telephone   may         mon  ...         1    999         0
# 1      telephone   may         mon  ...         1    999         0
# 2      telephone   may         mon  ...         1    999         0
# 3      telephone   may         mon  ...         1    999         0
# 4      telephone   may         mon  ...         1    999         0
# ...          ...   ...         ...  ...       ...    ...       ...
# 41183   cellular   nov         fri  ...         1    999         0
# 41184   cellular   nov         fri  ...         1    999         0
# 41185   cellular   nov         fri  ...         2    999         0
# 41186   cellular   nov         fri  ...         1    999         0
# 41187   cellular   nov         fri  ...         3    999         1
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 0      nonexistent          1.1          93.994          -36.4      4.857
# 1      nonexistent          1.1          93.994          -36.4      4.857
# 2      nonexistent          1.1          93.994          -36.4      4.857
# 3      nonexistent          1.1          93.994          -36.4      4.857
# 4      nonexistent          1.1          93.994          -36.4      4.857
# ...            ...          ...             ...            ...        ...
# 41183  nonexistent         -1.1          94.767          -50.8      1.028
# 41184  nonexistent         -1.1          94.767          -50.8      1.028
# 41185  nonexistent         -1.1          94.767          -50.8      1.028
# 41186  nonexistent         -1.1          94.767          -50.8      1.028
# 41187      failure         -1.1          94.767          -50.8      1.028
#
#        nr.employed    y
# 0           5191.0   no
# 1           5191.0   no
# 2           5191.0   no
# 3           5191.0   no
# 4           5191.0   no
# ...            ...  ...
# 41183       4963.6  yes
# 41184       4963.6   no
# 41185       4963.6   no
# 41186       4963.6  yes
# 41187       4963.6   no
#
# [41188 rows x 21 columns]

# %% [markdown]
# The Bank Marketing dataset from UCI is a popular dataset hsfrequently used in machine learning and data science projects.
#
# https://archive.ics.uci.edu/ml/datasets/Bank+Marketing
#
# Input variables from the data:
#
# ### Client data
# 1. age (numeric)
# 2. job : type of job (categorical: 'admin.','blue-collar','entrepreneur','housemaid','management','retired','self-employed','services','student','technician','unemployed','unknown')
# 3. marital : marital status (categorical: 'divorced','married','single','unknown'; note: 'divorced' means divorced or widowed)
# 4. education (categorical: 'basic.4y','basic.6y','basic.9y','high.school','illiterate','professional.course','university.degree','unknown')
# 5. default: has credit in default? (categorical: 'no','yes','unknown')
# 6. housing: has housing loan? (categorical: 'no','yes','unknown')
# 7. loan: has personal loan? (categorical: 'no','yes','unknown')
# ### related with the last contact of the current campaign:
# 8. contact: contact communication type (categorical: 'cellular','telephone')
# 9. month: last contact month of year (categorical: 'jan', 'feb', 'mar', ..., 'nov', 'dec')
# 10. day_of_week: last contact day of the week (categorical: 'mon','tue','wed','thu','fri')
# 11. duration: last contact duration, in seconds (numeric). Important note: this attribute highly affects the output target (e.g., if duration=0 then y='no'). Yet, the duration is not known before a call is performed. Also, after the end of the call y is obviously known. Thus, this input should only be included for benchmark purposes and should be discarded if the intention is to have a realistic predictive model.
# ### other attributes:
# 12. campaign: number of contacts performed during this campaign and for this client (numeric, includes last contact)
# 13. pdays: number of days that passed by after the client was last contacted from a previous campaign (numeric; 999 means client was not previously contacted)
# 14. previous: number of contacts performed before this campaign and for this client (numeric)
# 15. poutcome: outcome of the previous marketing campaign (categorical: 'failure','nonexistent','success')
# ### social and economic context attributes
# 16. emp.var.rate: employment variation rate. quarterly indicator (numeric)
# 17. cons.price.idx: consumer price index. monthly indicator (numeric)
# 18. cons.conf.idx: consumer confidence index. monthly indicator (numeric)
# 19. euribor3m: euribor 3 month rate. daily indicator (numeric)
# 20. nr.employed: number of employees. quarterly indicator (numeric)
#
# ### Output variable (desired target):
# 21. y. has the client subscribed a term deposit? (binary: 'yes','no')

# %%
bank.y
# Out:
# 0         no
# 1         no
# 2         no
# 3         no
# 4         no
#         ...
# 41183    yes
# 41184     no
# 41185     no
# 41186    yes
# 41187     no
# Name: y, Length: 41188, dtype: object

# %%
bank.y.value_counts()
# Out:
# y
# no     36548
# yes     4640
# Name: count, dtype: int64

# %% [markdown]
# ## Use Pandas to Explore

# %%
(bank
.assign(success=(bank.y == 'yes').astype(int))
.select_dtypes('number')
.corr(method='spearman')
.style
.background_gradient(cmap='RdBu', vmin=-1, vmax=1)
)
# Out:
# <style type="text/css">
# #T_cc509_row0_col0, #T_cc509_row1_col1, #T_cc509_row2_col2, #T_cc509_row3_col3, #T_cc509_row4_col4, #T_cc509_row5_col5, #T_cc509_row6_col6, #T_cc509_row7_col7, #T_cc509_row8_col8, #T_cc509_row9_col9, #T_cc509_row10_col10 {
#   background-color: #053061;
#   color: #f1f1f1;
# }
# #T_cc509_row0_col1, #T_cc509_row0_col3, #T_cc509_row1_col0, #T_cc509_row2_col7, #T_cc509_row3_col0, #T_cc509_row7_col2 {
#   background-color: #f7f6f6;
#   color: #000000;
# }
# #T_cc509_row0_col2, #T_cc509_row1_col6, #T_cc509_row2_col0, #T_cc509_row6_col1 {
#   background-color: #f6f7f7;
#   color: #000000;
# }
# #T_cc509_row0_col4, #T_cc509_row0_col10, #T_cc509_row1_col7, #T_cc509_row4_col0, #T_cc509_row7_col1, #T_cc509_row10_col0 {
#   background-color: #f7f5f4;
#   color: #000000;
# }
# #T_cc509_row0_col5, #T_cc509_row0_col6, #T_cc509_row0_col9, #T_cc509_row1_col4, #T_cc509_row4_col1, #T_cc509_row5_col0, #T_cc509_row6_col0, #T_cc509_row7_col10, #T_cc509_row9_col0, #T_cc509_row10_col7 {
#   background-color: #eff3f5;
#   color: #000000;
# }
# #T_cc509_row0_col7, #T_cc509_row7_col0 {
#   background-color: #e1edf3;
#   color: #000000;
# }
# #T_cc509_row0_col8, #T_cc509_row8_col0 {
#   background-color: #edf2f5;
#   color: #000000;
# }
# #T_cc509_row1_col2, #T_cc509_row1_col3, #T_cc509_row1_col8, #T_cc509_row2_col1, #T_cc509_row3_col1, #T_cc509_row8_col1 {
#   background-color: #f9ebe3;
#   color: #000000;
# }
# #T_cc509_row1_col5, #T_cc509_row2_col10, #T_cc509_row5_col1, #T_cc509_row10_col2 {
#   background-color: #f9eee7;
#   color: #000000;
# }
# #T_cc509_row1_col9, #T_cc509_row9_col1 {
#   background-color: #fae9df;
#   color: #000000;
# }
# #T_cc509_row1_col10, #T_cc509_row10_col1 {
#   background-color: #a2cde3;
#   color: #000000;
# }
# #T_cc509_row2_col3, #T_cc509_row3_col2, #T_cc509_row3_col6, #T_cc509_row6_col3 {
#   background-color: #ecf2f5;
#   color: #000000;
# }
# #T_cc509_row2_col4, #T_cc509_row4_col2 {
#   background-color: #faeae1;
#   color: #000000;
# }
# #T_cc509_row2_col5, #T_cc509_row5_col2 {
#   background-color: #d8e9f1;
#   color: #000000;
# }
# #T_cc509_row2_col6, #T_cc509_row6_col2 {
#   background-color: #e4eef4;
#   color: #000000;
# }
# #T_cc509_row2_col8, #T_cc509_row8_col2 {
#   background-color: #ddebf2;
#   color: #000000;
# }
# #T_cc509_row2_col9, #T_cc509_row9_col2 {
#   background-color: #dbeaf2;
#   color: #000000;
# }
# #T_cc509_row3_col4, #T_cc509_row4_col3 {
#   background-color: #e37e64;
#   color: #f1f1f1;
# }
# #T_cc509_row3_col5, #T_cc509_row5_col3 {
#   background-color: #c7e0ed;
#   color: #000000;
# }
# #T_cc509_row3_col7, #T_cc509_row7_col3 {
#   background-color: #f9ede5;
#   color: #000000;
# }
# #T_cc509_row3_col8, #T_cc509_row8_col3 {
#   background-color: #b8d8e9;
#   color: #000000;
# }
# #T_cc509_row3_col9, #T_cc509_row9_col3 {
#   background-color: #b3d6e8;
#   color: #000000;
# }
# #T_cc509_row3_col10, #T_cc509_row10_col3 {
#   background-color: #f7b99c;
#   color: #000000;
# }
# #T_cc509_row4_col5, #T_cc509_row5_col4 {
#   background-color: #ef9979;
#   color: #000000;
# }
# #T_cc509_row4_col6, #T_cc509_row6_col4, #T_cc509_row9_col10, #T_cc509_row10_col9 {
#   background-color: #f9c4a9;
#   color: #000000;
# }
# #T_cc509_row4_col7, #T_cc509_row7_col4 {
#   background-color: #fae7dc;
#   color: #000000;
# }
# #T_cc509_row4_col8, #T_cc509_row8_col4 {
#   background-color: #eb9172;
#   color: #f1f1f1;
# }
# #T_cc509_row4_col9, #T_cc509_row9_col4 {
#   background-color: #ee9677;
#   color: #000000;
# }
# #T_cc509_row4_col10, #T_cc509_row10_col4 {
#   background-color: #d1e5f0;
#   color: #000000;
# }
# #T_cc509_row5_col6, #T_cc509_row6_col5 {
#   background-color: #3783bb;
#   color: #f1f1f1;
# }
# #T_cc509_row5_col7, #T_cc509_row7_col5 {
#   background-color: #cae1ee;
#   color: #000000;
# }
# #T_cc509_row5_col8, #T_cc509_row5_col9, #T_cc509_row8_col5, #T_cc509_row9_col5 {
#   background-color: #0d3f76;
#   color: #f1f1f1;
# }
# #T_cc509_row5_col10, #T_cc509_row10_col5 {
#   background-color: #fbceb7;
#   color: #000000;
# }
# #T_cc509_row6_col7, #T_cc509_row7_col6 {
#   background-color: #c2ddec;
#   color: #000000;
# }
# #T_cc509_row6_col8, #T_cc509_row8_col6 {
#   background-color: #6eaed2;
#   color: #f1f1f1;
# }
# #T_cc509_row6_col9, #T_cc509_row9_col6 {
#   background-color: #78b4d5;
#   color: #000000;
# }
# #T_cc509_row6_col10, #T_cc509_row10_col6 {
#   background-color: #fbe6da;
#   color: #000000;
# }
# #T_cc509_row7_col8, #T_cc509_row8_col7 {
#   background-color: #c5dfec;
#   color: #000000;
# }
# #T_cc509_row7_col9, #T_cc509_row9_col7 {
#   background-color: #deebf2;
#   color: #000000;
# }
# #T_cc509_row8_col9, #T_cc509_row9_col8 {
#   background-color: #0f437b;
#   color: #f1f1f1;
# }
# #T_cc509_row8_col10, #T_cc509_row10_col8 {
#   background-color: #fac8af;
#   color: #000000;
# }
# </style>
# <table id="T_cc509">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cc509_level0_col0" class="col_heading level0 col0" >age</th>
#       <th id="T_cc509_level0_col1" class="col_heading level0 col1" >duration</th>
#       <th id="T_cc509_level0_col2" class="col_heading level0 col2" >campaign</th>
#       <th id="T_cc509_level0_col3" class="col_heading level0 col3" >pdays</th>
#       <th id="T_cc509_level0_col4" class="col_heading level0 col4" >previous</th>
#       <th id="T_cc509_level0_col5" class="col_heading level0 col5" >emp.var.rate</th>
#       <th id="T_cc509_level0_col6" class="col_heading level0 col6" >cons.price.idx</th>
#       <th id="T_cc509_level0_col7" class="col_heading level0 col7" >cons.conf.idx</th>
#       <th id="T_cc509_level0_col8" class="col_heading level0 col8" >euribor3m</th>
#       <th id="T_cc509_level0_col9" class="col_heading level0 col9" >nr.employed</th>
#       <th id="T_cc509_level0_col10" class="col_heading level0 col10" >success</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cc509_level0_row0" class="row_heading level0 row0" >age</th>
#       <td id="T_cc509_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_cc509_row0_col1" class="data row0 col1" >-0.002123</td>
#       <td id="T_cc509_row0_col2" class="data row0 col2" >0.005715</td>
#       <td id="T_cc509_row0_col3" class="data row0 col3" >-0.001062</td>
#       <td id="T_cc509_row0_col4" class="data row0 col4" >-0.012643</td>
#       <td id="T_cc509_row0_col5" class="data row0 col5" >0.045003</td>
#       <td id="T_cc509_row0_col6" class="data row0 col6" >0.044790</td>
#       <td id="T_cc509_row0_col7" class="data row0 col7" >0.114536</td>
#       <td id="T_cc509_row0_col8" class="data row0 col8" >0.054391</td>
#       <td id="T_cc509_row0_col9" class="data row0 col9" >0.044789</td>
#       <td id="T_cc509_row0_col10" class="data row0 col10" >-0.011861</td>
#     </tr>
#     <tr>
#       <th id="T_cc509_level0_row1" class="row_heading level0 row1" >duration</th>
#       <td id="T_cc509_row1_col0" class="data row1 col0" >-0.002123</td>
#       <td id="T_cc509_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_cc509_row1_col2" class="data row1 col2" >-0.080953</td>
#       <td id="T_cc509_row1_col3" class="data row1 col3" >-0.083072</td>
#       <td id="T_cc509_row1_col4" class="data row1 col4" >0.042407</td>
#       <td id="T_cc509_row1_col5" class="data row1 col5" >-0.069201</td>
#       <td id="T_cc509_row1_col6" class="data row1 col6" >0.002854</td>
#       <td id="T_cc509_row1_col7" class="data row1 col7" >-0.008678</td>
#       <td id="T_cc509_row1_col8" class="data row1 col8" >-0.078346</td>
#       <td id="T_cc509_row1_col9" class="data row1 col9" >-0.095225</td>
#       <td id="T_cc509_row1_col10" class="data row1 col10" >0.348777</td>
#     </tr>
#     <tr>
#       <th id="T_cc509_level0_row2" class="row_heading level0 row2" >campaign</th>
#       <td id="T_cc509_row2_col0" class="data row2 col0" >0.005715</td>
#       <td id="T_cc509_row2_col1" class="data row2 col1" >-0.080953</td>
#       <td id="T_cc509_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_cc509_row2_col3" class="data row2 col3" >0.055514</td>
#       <td id="T_cc509_row2_col4" class="data row2 col4" >-0.087420</td>
#       <td id="T_cc509_row2_col5" class="data row2 col5" >0.156360</td>
#       <td id="T_cc509_row2_col6" class="data row2 col6" >0.096494</td>
#       <td id="T_cc509_row2_col7" class="data row2 col7" >-0.001554</td>
#       <td

# %%
(bank
 .assign(subscribed=(bank.y == 'yes').astype(int))
 .plot.scatter(x='pdays', y='campaign')
)
# Out:
# <AxesSubplot: xlabel='pdays', ylabel='campaign'>

# %%
(bank
 .assign(subscribed=(bank.y == 'yes').astype(int))
 .plot.scatter(x='pdays', y='campaign', logx=True, alpha=.1, c='subscribed', cmap='viridis')
)
# Out:
# <AxesSubplot: xlabel='pdays', ylabel='campaign'>

# %%
(bank
 .assign(subscribed=(bank.y == 'yes').astype(int))
 .plot.scatter(x='nr.employed', y='campaign',
               alpha=.1, c='subscribed', cmap='viridis')
)
# Out:
# <AxesSubplot: xlabel='nr.employed', ylabel='campaign'>

# %% [markdown]
# ## Out of Box Model

# %%
# cleanup
from feature_engine import encoding, imputation
import pandas as pd
from sklearn import base, compose, model_selection, pipeline, preprocessing


bank = pd.read_csv('/Users/matt/Downloads/bank-additional/bank-additional-full.csv', sep=';')

def tweak_bank(df):
    return (df
        .assign(**df.select_dtypes(object).astype('category'))
    )


class BankTransformer(base.BaseEstimator, base.TransformerMixin):
    def transform(self, X):
        return tweak_bank(X)
        
    def fit(self, X, y=None):
        return self

pl = pipeline.Pipeline(
    [('tweak', BankTransformer()),
     ('cat_encoder', encoding.OneHotEncoder(top_categories=5, drop_last=True)),
    ]
)

X_raw_train, X_raw_test, y_raw_train, y_raw_test = model_selection.train_test_split(
    bank.drop(columns='y'), bank.y, stratify=bank.y, random_state=42)
X_train = pl.fit_transform(X_raw_train)
X_test = pl.transform(X_raw_test)

label_encoder = preprocessing.LabelEncoder()
y_train = label_encoder.fit_transform(y_raw_train)
y_test = label_encoder.transform(y_raw_test)

# %%
# This data set isn't missing data, bug XGBoost handles that...
bank.isna().any()
# Out:
# age               False
# job               False
# marital           False
# education         False
# default           False
# housing           False
# loan              False
# contact           False
# month             False
# day_of_week       False
# duration          False
# campaign          False
# pdays             False
# previous          False
# poutcome          False
# emp.var.rate      False
# cons.price.idx    False
# cons.conf.idx     False
# euribor3m         False
# nr.employed       False
# y                 False
# dtype: bool

# %%
xg_oob = xgboost.XGBClassifier()
xg_oob.fit(X_train, y_train)
xg_oob.score(X_test, y_test)
# Out:
# 0.9185199572691075

# %%
# default tends to overfit
import matplotlib.pyplot as plt
from sklearn import metrics

fig, ax = plt.subplots(figsize=(8,4), ncols=1)
metrics.RocCurveDisplay.from_estimator(xg_oob,
                       X_train, y_train,ax=ax, label='default train')
metrics.RocCurveDisplay.from_estimator(xg_oob,
                       X_test, y_test,ax=ax, label='test')

# %% [markdown]
# ## Tuning

# %%
from hyperopt import fmin, tpe, hp, Trials
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from sklearn.metrics import accuracy_score, roc_auc_score  

from typing import Any, Dict, Union

def hyperparameter_tuning(space: Dict[str, Union[float, int]], 
                    X_train: pd.DataFrame, y_train: pd.Series, 
                    X_test: pd.DataFrame, y_test: pd.Series, 
                    early_stopping_rounds: int=50,
                    metric:callable=accuracy_score) -> Dict[str, Any]:

    int_vals = ['max_depth', 'reg_alpha']
    space = {k: (int(val) if k in int_vals else val)
             for k,val in space.items()}
    space['early_stopping_rounds'] = early_stopping_rounds
    model = xgboost.XGBClassifier(**space)
    evaluation = [(X_train, y_train),
                  (X_test, y_test)]
    model.fit(X_train, y_train,
              eval_set=evaluation, 
              verbose=False)    
         
    pred = model.predict(X_test)
    score = metric(y_test, pred)
    return {'loss': -score, 'status': STATUS_OK, 'model': model}

params = {'random_state': 42, 'eval_metric': 'aucpr'}

rounds = [{'max_depth': hp.quniform('max_depth', 1, 8, 1),  # tree
           'min_child_weight': hp.loguniform('min_child_weight', -2, 3)},
          {'scale_pos_weight':hp.uniform('scale_pos_weight', 0, 10), # imbalanced
           'max_delta_step':hp.uniform('max_delta_step', 0, 10)},
          {'subsample': hp.uniform('subsample', 0.5, 1),   # stochastic
           'colsample_bytree': hp.uniform('colsample_bytree', 0.5, 1)},
          {'reg_alpha': hp.uniform('reg_alpha', 0, 10),
            'reg_lambda': hp.uniform('reg_lambda', 1, 10),},
          {'gamma': hp.loguniform('gamma', -10, 10)}, # regularization
          {'learning_rate': hp.loguniform('learning_rate', -7, 0)} # boosting
]

all_trials = []
for round in rounds:
    params = {**params, **round}
    trials = Trials()
    best = fmin(fn=lambda space: hyperparameter_tuning(space, X_train, 
                                        y_train, X_test, y_test),            
        space=params,           
        algo=tpe.suggest,            
        max_evals=20,            
        trials=trials,
    )
    params = {**params, **best}
    all_trials.append(trials)
# Out:
#   0%|                                                                                                                                                                                                                                                      | 0/20 [00:00<?, ?trial/s, best loss=?]
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:299: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:301: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:332: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:323: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:299: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:301: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:332: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:323: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
#   5%|██████████▉                                                                                                                                                                                                                | 1/20 [00:01<00:28,  1.49s/trial, best loss: -0.9210449645527824]
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:299: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:301: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:332: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:323: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:299: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:301: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:332: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:323: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:299: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:301: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:332: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:323: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
#  10%|█████████████████████▉                                                                                                                                                                                                     | 2/20 [00:02<00:20,  1.13s/trial, best loss: -0.9210449645527824]
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:299: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:301: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:332: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:323: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:299: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:301: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:332: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:323: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:299: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:301: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:332: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:323: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
#  15%|████████████████████████████████▊                                                                                                                                                                                          | 3/20 [00:04<00:24,  1.44s/trial, best loss: -0.9210449645527824]
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:299: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:301: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:332: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:323: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:299: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:301: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:332: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:323: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:299: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:301: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:332: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:323: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
#  20%|███████████████████████████████████████████▊                                                                                                                                                                               | 4/20 [00:05<00:24,  1.53s/trial, best loss: -0.9210449645527824]
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:299: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:301: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:332: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:323: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:299: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:301: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:332: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:323: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:299: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:301: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:332: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:323: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
#  25%|██████████████████████████████████████████████████████▊                                                                                                                                                                    | 5/20 [00:07<00:21,  1.43s/trial, best loss: -0.9210449645527824]
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:299: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:301: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:332: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:323: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:299: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:301: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:332: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:323: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:299: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:301: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:332: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:323: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
#  30%|█████████████████████████████████████████████████████████████████▋                                                                                                                                                         | 6/20 [00:08<00:22,  1.58s/trial, best loss: -0.9210449645527824]
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:299: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:301: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:332: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:323: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:299: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:301: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:332: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:323: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:299: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:301: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:332: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:323: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
#  35%|████████████████████████████████████████████████████████████████████████████▋                                                                                                                                              | 7/20 [00:10<00:19,  1.51s/trial, best loss: -0.9210449645527824]
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:299: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:301: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:332: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:323: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:299: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:301: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:332: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:323: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:299: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:301: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:332: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:323: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
#  40%|███████████████████████████████████████████████████████████████████████████████████████▌                                                                                                                                   | 8/20 [00:12<00:19,  1.65s/trial, best loss: -0.9210449645527824]
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:299: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:301: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:332: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:323: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:299: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:301: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:332: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:323: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:299: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:301: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:332: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:323: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
#  45%|██████████████████████████████████████████████████████████████████████████████████████████████████▌                                                                                                                        | 9/20 [00:14<00:20,  1.85s/trial, best loss: -0.9210449645527824]
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:299: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:301: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:332: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:323: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:299: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:301: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:332: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:323: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:299: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:301: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:332: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:323: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
#  50%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████                                                                                                             | 10/20 [00:16<00:18,  1.90s/trial, best loss: -0.9210449645527824]
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:299: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:301: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:332: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:323: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:299: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:301: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:332: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:323: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:299: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:301: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:332: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:323: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
#  55%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉                                                                                                  | 11/20 [00:18<00:16,  1.85s/trial, best loss: -0.9210449645527824]
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:299: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:301: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:332: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:323: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:299: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:301: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:332: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:323: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:299: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:301: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:332: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:323: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
#  60%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊                                                                                       | 12/20 [00:20<00:15,  1.91s/trial, best loss: -0.9210449645527824]
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:299: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:301: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:332: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:323: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:299: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:301: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:332: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:323: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:299: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:301: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:332: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:323: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
#  65%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋                                                                            | 13/20 [00:22<00:13,  1.97s/trial, best loss: -0.9210449645527824]
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:299: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:301: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:332: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:323: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:299: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:301: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:332: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:323: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:299: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:301: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:332: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:323: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
#  70%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                                                                 | 14/20 [00:24<00:11,  1.87s/trial, best loss: -0.9211420802175391]
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:299: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:301: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:332: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:323: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:299: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
#
# ...
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:299: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:301: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:332: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:323: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
#  80%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                                            | 16/20 [00:38<00:09,  2.34s/trial, best loss: -0.92259881518889]
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:299: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:301: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:332: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:323: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:299: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:301: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:332: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:323: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:299: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:301: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:332: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:323: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
#  85%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                                 | 17/20 [00:41<00:07,  2.52s/trial, best loss: -0.92259881518889]
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:299: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:301: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:332: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:323: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:299: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:301: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:332: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:323: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:299: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:301: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:332: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:323: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
#  90%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                     | 18/20 [00:43<00:04,  2.34s/trial, best loss: -0.9241526658249976]
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:299: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:301: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:332: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:323: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:299: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:301: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:332: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:323: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:299: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:301: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:332: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:323: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
#  95%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████           | 19/20 [00:46<00:02,  2.60s/trial, best loss: -0.9241526658249976]
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:299: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:301: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:332: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:323: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:299: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:301: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:332: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:323: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:299: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:301: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:332: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:323: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 20/20 [00:49<00:00,  2.48s/trial, best loss: -0.9241526658249976]
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:299: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:301: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:332: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
#
# /Users/matt/.envs/menv/lib/python3.10/site-packages/xgboost/data.py:323: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)

# %%
params
# Out:
# {'random_state': 42,
#  'eval_metric': 'aucpr',
#  'max_depth': 6.0,
#  'min_child_weight': 0.8151600069304076,
#  'scale_pos_weight': 1.2026016321282018,
#  'max_delta_step': 5.091721870274579,
#  'subsample': 0.8097593507818586,
#  'colsample_bytree': 0.9612077912988541,
#  'reg_alpha': 2.453169661989615,
#  'reg_lambda': 8.12521434799851,
#  'gamma': 0.04248677095273474,
#  'learning_rate': 0.3282663008031524}

# %%
step_params = {'random_state': 42,
 'eval_metric': 'aucpr',
 'max_depth': 6,
 'min_child_weight': 0.8151600069304076,
 'scale_pos_weight': 1.2026016321282018,
 'max_delta_step': 5.091721870274579,
 'subsample': 0.8097593507818586,
 'colsample_bytree': 0.9612077912988541,
 'reg_alpha': 2.453169661989615,
 'reg_lambda': 8.12521434799851,
 'gamma': 0.04248677095273474,
 'learning_rate': 0.3282663008031524}

# %%
xg_step = xgboost.XGBClassifier(**step_params, early_stopping_rounds=100, n_estimators=250)
xg_step.fit(X_train, y_train, eval_set=[(X_train, y_train),
                                        (X_test, y_test)], 
           verbose=100)
xg_step.score(X_test, y_test)
# Out:
# [0]	validation_0-aucpr:0.64165	validation_1-aucpr:0.64155
# [100]	validation_0-aucpr:0.87730	validation_1-aucpr:0.65573
# [119]	validation_0-aucpr:0.89776	validation_1-aucpr:0.65146
# 0.9226959308536467

# %%
xg_oob.score(X_test, y_test)
# Out:
# 0.9185199572691075

# %%
import matplotlib.pyplot as plt
from sklearn import metrics

fig, axes = plt.subplots(figsize=(8,4), ncols=2)
metrics.RocCurveDisplay.from_estimator(xg_oob,
                       X_train, y_train,ax=axes[0], label='default train')
metrics.RocCurveDisplay.from_estimator(xg_oob,
                       X_test, y_test,ax=axes[0])
axes[0].set(title='ROC plots for default model')

metrics.RocCurveDisplay.from_estimator(xg_step,
                       X_train, y_train,ax=axes[1], label='step train')
metrics.RocCurveDisplay.from_estimator(xg_step,
                       X_test, y_test,ax=axes[1])#, label='step test')
axes[1].set(title='ROC plots for stepwise model')
# Out:
# [Text(0.5, 1.0, 'ROC plots for stepwise model')]

# %% [markdown]
# ## Feature Interactions

# %%
# !pip install xgbfir
# Out:
# Collecting xgbfir
#   Downloading xgbfir-0.3.1-py2.py3-none-any.whl (8.3 kB)
# Requirement already satisfied: xlsxwriter>=0.9.3 in /Users/matt/.envs/menv/lib/python3.10/site-packages (from xgbfir) (3.1.2)
# Installing collected packages: xgbfir
# Successfully installed xgbfir-0.3.1

# %%
import xgbfir
xgbfir.saveXgbFI(xg_step, feature_names=X_test.columns, OutputXlsxFile='/tmp/fir.xlsx')

# %%
fir = pd.read_excel('/tmp/fir.xlsx')
fir
# Out:
#                       Interaction         Gain  FScore     wFScore  \
# 0                        duration  9867.030727     928  153.886157
# 1                     nr.employed  4667.340367      45   11.958373
# 2                       euribor3m  2517.455921     579  113.514734
# 3                             age  1301.946266     625   74.288560
# 4                   cons.conf.idx  1009.788396     158   27.974492
# 5                  cons.price.idx   777.578298     174   23.562715
# 6                    emp.var.rate   652.837620      77   11.485353
# 7                        campaign   495.814155     232   25.526402
# 8                           pdays   487.759770      87   14.194134
# 9                 day_of_week_mon   191.527323      76    5.422521
# 10               contact_cellular   171.181467      54    6.665345
# 11                day_of_week_thu   157.192928      78    7.255421
# 12    education_university.degree   135.476016      64    7.421893
# 13               poutcome_success   133.751348      12    1.314634
# 14                       previous   130.623552      63    7.512491
# 15                day_of_week_fri   126.260103      52    5.851608
# 16                 job_technician   107.204799      58    4.362321
# 17               poutcome_failure   103.747023      37    4.273986
# 18                     default_no   103.714057      34    4.986905
# 19                day_of_week_wed   102.232468      51    3.793766
# 20                job_blue-collar   101.885092      43    4.754165
# 21             education_basic.9y   101.197774      48    6.741744
# 22          education_high.school    98.296331      55    6.615772
# 23                day_of_week_tue    91.537061      55    2.684286
# 24                     job_admin.    89.119524      43    4.173729
# 25  education_professional.course    85.383886      47    5.124961
# 26                 marital_single    78.166362      39    4.722499
# 27             education_basic.4y    77.025672      48    6.404872
# 28                 job_management    75.273653      41    4.242872
# 29                marital_married    73.344980      41    1.080264
# 30                        loan_no    72.455740      43    3.044236
# 31                     housing_no    70.421572      41    3.723564
# 32                       loan_yes    69.218992      41    2.578547
# 33                      month_jul    61.317990      24    2.400057
# 34                    housing_yes    58.829624      35    2.847954
# 35                      month_may    54.801371      22    1.773804
# 36                   job_services    50.800799      34    4.031415
# 37               marital_divorced    42.706577      30    2.264395
# 38                      month_nov    34.899731      21    3.174858
# 39                      month_jun    32.235460      19    1.872661
# 40                      month_aug    30.175848      14    0.739489
# 41                housing_unknown    14.834861      10    1.161631
# 42                default_unknown     4.754914       3    0.034129
# 43           poutcome_nonexistent     2.328031       2    0.026145
# 44                marital_unknown     1.458824       1    0.162555
# 45              contact_telephone     0.338890       1    0.009010
#
#     Average wFScore  Average Gain  Expected Gain  Gain Rank  FScore Rank  \
# 0          0.165826     10.632576    5980.674709          1            1
# 1          0.265742    103.718675    4021.658432          2           22
# 2          0.196053      4.347938     654.203843          3            3
# 3          0.118862      2.083114     201.500089          4            2
# 4          0.177054      6.391066     468.616487          5            6
# 5          0.135418      4.468841     105.148226          6            5
# 6          0.149160      8.478411     221.988280          7            9
# 7          0.110028      2.137130      69.050052          8            4
# 8          0.163151      5.606434      65.918382          9            7
# 9          0.071349      2.520096      15.474955         10           10
# 10         0.123432      3.170027      21.219392         11           16
# 11         0.093018      2.015294      15.831332         12            8
# 12         0.115967      2.116813      18.558615         13           11
# 13         0.109553     11.145946      21.300510         14           41
# 14         0.119246      2.073390      20.808851         15           12
# 15         0.112531      2.428079      16.282239         16           17
# 16         0.075212      1.848359      10.535297         17           13
# 17         0.115513      2.803974      20.757039         18           31
# 18         0.146674      3.050413      28.696467         19           33
# 19         0.074388      2.004558       9.610006         20           18
# 20         0.110562      2.369421      17.998417         21           23
# 21         0.140453      2.108287      17.113736         22           19
# 22         0.120287      1.787206      13.226094         23           14
# 23         0.048805      1.664310       6.932632         24           15
# 24         0.097063      2.072547       9.858428         25           24
# 25         0.109042      1.816678      10.138931         26           21
# 26         0.121090      2.004266      10.210896         27           30
# 27         0.133435      1.604702      15.688305         28           20
# 28         0.103485      1.835943       8.486279         29           26
# 29         0.026348      1.788902       2.885977         30           27
# 30         0.070796      1.685017       7.754126         31           25
# 31         0.090819      1.717599       9.322412         32           28
# 32         0.062891      1.688268       5.868676         33           29
# 33         0.100002      2.554916       6.011212         34           36
# 34         0.081370      1.680846       6.554012         35           32
# 35         0.080627      2.490971       5.183323         36           37
# 36         0.118571      1.494141       7.517515         37           34
# 37         0.075480      1.423553       4.336401         38           35
# 38         0.151184      1.661892       6.184925         39           38
# 39         0.098561      1.696603       6.352347         40           39
# 40         0.052821      2.155418       1.548283         41           40
# 41         0.116163      1.483486       2.393723         42           42
# 42         0.011376      1.584971       0.066353         43           43
# 43         0.013073      1.164015       0.029900         44           44
# 44         0.162555      1.458824       0.237139         45           45
# 45         0.009010      0.338890       0.003053         46           46
#
#     wFScore Rank  Avg wFScore Rank  Avg Gain Rank  Expected Gain Rank  \
# 0              1                 4              3                   1
# 1              8                 1              1                   2
# 2              2                 2              8                   3
# 3              3                17             21                   6
# 4              4                 3              5                   4
# 5              6                11              7                   7
# 6              9                 8              4                   5
# 7              5                24             18                   8
# 8              7                 5              6                   9
# 9             18                38             13                  21
# 10            14                13              9                  12
# 11            12                31             24                  19
# 12            11                20             19                  15
# 13            39                25              2                  11
# 14            10                16             22                  13
# 15            17                22             15                  18
# 16            23                36             27                  23
# 17            24                21             11                  14
# 18            20                 9             10                  10
# 19            28                37             25                  27
# 20            21                23             16                  16
# 21            13                10             20                  17
# 22            15                15             31                  22
# 23            33                42             37                  32
# 24            26                30             23                  26
# 25            19                26             29                  25
# 26            22                14             26                  24
# 27            16                12             39                  20
# 28            25                27             28                  29
# 29            41                43             30                  40
# 30            31                39             35                  30
# 31            29                32             32                  28
# 32            34                40             34                  37
# 33            35                28             12                  36
# 34            32                33             36                  33
# 35            38                34             14                  38
# 36            27                18             41                  31
# 37            36                35             44                  39
# 38            30                 7             38                  35
# 39            37                29             33                  34
# 40            42                41             17                  42
# 41            40                19             42                  41
# 42            44                45             40                  44
# 43            45                44             45                  45
# 44            43                 6             43                  43
# 45            46                46             46                  46
#
#     Average Rank  Average Tree Index  Average Tree Depth
# 0       1.833333           49.635776            3.783405
# 1       6.000000           41.422222            3.133333
# 2       3.500000           44.699482            3.639033
# 3       8.833333           53.182400            4.044800
# 4       4.500000           50.075949            3.613924
# 5       7.000000           45.287356            3.747126
# 6       7.000000           39.168831            3.805195
# 7      11.166667           51.948276            3.875000
# 8       7.166667           39.356322            3.770115
# 9      18.333333           51.039474            4.065789
# 10     12.500000           47.925926            3.907407
# 11     17.666667           54.500000            3.935897
# 12     14.833333           57.921875            4.171875
# 13     22.000000           41.916667            3.333333
# 14     14.666667           52.158730            3.920635
# 15     17.500000           57.000000            3.903846
# 16     23.166667           49.293103            4.241379
# 17     19.833333           51.594595            3.891892
# 18     16.833333           54.911765            3.882353
# 19     25.833333           53.784314            4.176471
# 20     20.000000           54.465116            3.906977
# 21     16.833333           49.583333            3.729167
# 22     20.000000           54.218182            3.945455
# 23     30.500000           54.145455            4.054545
# 24     25.666667           48.720930            4.209302
# 25     24.333333           54.680851            3.936170
# 26     23.833333           50.512821            3.769231
# 27     22.500000           56.312500            3.604167
# 28     27.333333           47.365854            3.804878
# 29     35.166667           55.853659            4.341463
# 30     31.833333           55.418605            4.023256
# 31     30.166667           62.292683            3.975610
# 32     34.500000           50.682927            4.268293
# 33     30.166667           46.875000            4.125000
# 34     33.500000           59.714286            3.971429
# 35     32.833333           53.454545            3.727273
# 36     31.333333           51.205882            3.970588
# 37     37.833333           53.200000            4.200000
# 38     31.166667           51.952381            3.571429
# 39     35.333333           46.736842            4.263158
# 40     37.166667           46.785714            4.071429
# 41     37.666667           36.400000            3.900000
# 42     43.166667           37.000000            4.666667
# 43     44.500000           20.000000            4.000000
# 44     37.500000            8.000000            4.000000
# 45     46.000000           79.000000            5.000000

# %%
fir2 = pd.read_excel('/tmp/fir.xlsx', sheet_name='Interaction Depth 1')
fir2
# Out:
#                                 Interaction          Gain  FScore    wFScore  \
# 0                      duration|nr.employed  15285.640256      28   8.380713
# 1                        duration|euribor3m   6073.981189     262  36.409077
# 2                         duration|duration   5483.171553     213  40.066439
# 3                 cons.conf.idx|nr.employed   3034.832983       8   3.475997
# 4                    cons.conf.idx|duration   2998.001262      77  13.539348
# ..                                      ...           ...     ...        ...
# 95                       age|job_technician     55.910291      17   0.349515
# 96                      age|day_of_week_tue     55.249092      13   0.844198
# 97  education_professional.course|euribor3m     54.806895      13   1.036262
# 98                    euribor3m|housing_yes     54.622533      12   1.495331
# 99                         age|emp.var.rate     54.416869      15   0.740833
#
#     Average wFScore  Average Gain  Expected Gain  Gain Rank  FScore Rank  \
# 0          0.299311    545.915723    8447.446870          1           21
# 1          0.138966     23.183134    1253.528379          2            1
# 2          0.188105     25.742589     961.634276          3            3
# 3          0.434500    379.354123    1996.507574          4           87
# 4          0.175836     38.935081    1720.419866          5            9
# ..              ...           ...            ...        ...          ...
# 95         0.020560      3.288841       1.823188         96           52
# 96         0.064938      4.249930       4.090479         97           67
# 97         0.079712      4.215915       4.092527         98           68
# 98         0.124611      4.551878       7.238533         99           73
# 99         0.049389      3.627791       3.224026        100           59
#
#     wFScore Rank  Avg wFScore Rank  Avg Gain Rank  Expected Gain Rank  \
# 0             12                 3              1                   1
# 1              2                30             16                   4
# 2              1                15             14                   5
# 3             23                 1              2                   2
# 4              7                19              7                   3
# ..           ...               ...            ...                 ...
# 95            95                98            100                  98
# 96            81                76             89                  88
# 97            71                68             90                  87
# 98            53                43             81                  74
# 99            84                88             99                  93
#
#     Average Rank  Average Tree Index  Average Tree Depth
# 0       6.500000           30.392857            2.357143
# 1       9.166667           42.893130            3.782443
# 2       6.833333           54.169014            3.882629
# 3      19.833333            7.750000            2.500000
# 4       8.333333           50.844156            3.649351
# ..           ...                 ...                 ...
# 95     89.833333           44.823529            4.705882
# 96     83.000000           55.230769            3.769231
# 97     80.333333           63.846154            4.000000
# 98     70.500000           53.416667            4.083333
# 99     87.166667           49.066667            4.733333
#
# [100 rows x 16 columns]

# %% [markdown]
# ## Interpretation

# %%
(pd.Series(xg_step.feature_importances_, index=X_train.columns)
 .sort_values()
 .plot.barh(figsize=(4, 10))
)
# Out:
# <AxesSubplot: >

# %%
xgboost.plot_tree(xg_step, num_trees=0, rankdir='LR')
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## SHAP

# %%
import shap
shap.initjs()

shap_ex = shap.TreeExplainer(xg_step)
vals = shap_ex(X_test)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
shap.plots.beeswarm(vals)

# %%
shap.plots.scatter(vals[:, 'duration'], color=vals)

# %%
fig, ax = plt.subplots(figsize=(10,4))
ax.set_xscale('log')
shap.plots.scatter(vals[:, 'duration'], color=vals[:, 'nr.employed'],
                 ax=ax, alpha=.2
)

# %%
shap.plots.scatter(vals[:, 'nr.employed'], color=vals)

# %%
shap.plots.scatter(vals[:, 'nr.employed'], color=vals, x_jitter=0)

# %%
X_test
# Out:
#        age  duration  campaign  pdays  previous  emp.var.rate  cons.price.idx  \
# 31165   41       597         1    999         0          -1.8          92.893
# 26855   31        41         1    999         0          -0.1          93.200
# 38292   56        79         2    999         0          -3.4          92.431
# 8532    32       355         1    999         0           1.4          94.465
# 25472   32       104         1    999         0          -0.1          93.200
# ...    ...       ...       ...    ...       ...           ...             ...
# 2225    35       159         3    999         0           1.1          93.994
# 23672   35        35        10    999         0           1.4          93.444
# 12770   40       144         1    999         0           1.4          93.918
# 4177    56       112         7    999         0           1.1          93.994
# 10252   35       114         5    999         0           1.4          94.465
#
#        cons.conf.idx  euribor3m  nr.employed  ...  month_jun  month_nov  \
# 31165          -46.2      1.334       5099.1  ...          0          0
# 26855          -42.0      4.076       5195.8  ...          0          1
# 38292          -26.9      0.742       5017.5  ...          0          0
# 8532           -41.8      4.864       5228.1  ...          1          0
# 25472          -42.0      4.120       5195.8  ...          0          1
# ...              ...        ...          ...  ...        ...        ...
# 2225           -36.4      4.857       5191.0  ...          0          0
# 23672          -36.1      4.962       5228.1  ...          0          0
# 12770          -42.7      4.962       5228.1  ...          0          0
# 4177           -36.4      4.858       5191.0  ...          0          0
# 10252          -41.8      4.960       5228.1  ...          1          0
#
#        day_of_week_thu  day_of_week_mon  day_of_week_wed  day_of_week_tue  \
# 31165                0                0                1                0
# 26855                1                0                0                0
# 38292                0                0                1                0
# 8532                 0                0                1                0
# 25472                0                0                1                0
# ...                ...              ...              ...              ...
# 2225                 0                1                0                0
# 23672                1                0                0                0
# 12770                0                0                0                1
# 4177                 0                1                0                0
# 10252                0                1                0                0
#
#        day_of_week_fri  poutcome_nonexistent  poutcome_failure  \
# 31165                0                     1                 0
# 26855                0                     1                 0
# 38292                0                     1                 0
# 8532                 0                     1                 0
# 25472                0                     1                 0
# ...                ...                   ...               ...
# 2225                 0                     1                 0
# 23672                0                     1                 0
# 12770                0                     1                 0
# 4177                 0                     1                 0
# 10252                0                     1                 0
#
#        poutcome_success
# 31165                 0
# 26855                 0
# 38292                 0
# 8532                  0
# 25472                 0
# ...                 ...
# 2225                  0
# 23672                 0
# 12770                 0
# 4177                  0
# 10252                 0
#
# [10297 rows x 48 columns]

# %%
xg_step.predict_proba(X_test.loc[[31165]])
# Out:
# array([[0.61906236, 0.38093764]], dtype=float32)

# %%
xg_step.predict(X_test.loc[[31165]])
# Out:
# array([0])

# %%
# 0 is the first entry that has index 31165 in our data
shap.plots.waterfall(vals[0])

# %% [markdown]
# ## Constraints

# %%
shap.plots.partial_dependence(ind='duration',
      model=lambda rows: xg_step.predict_proba(rows)[:,-1],
      data=X_train)

# %%
shap.plots.partial_dependence(ind='pdays',
      model=lambda rows: xg_step.predict_proba(rows)[:,-1],
      data=X_train)

# %%
shap.plots.partial_dependence(ind='nr.employed',
      model=lambda rows: xg_step.predict_proba(rows)[:,-1],
      data=X_train)

# %%
xg_const = xgboost.XGBClassifier(**step_params, early_stopping_rounds=20, 
                            monotone_constraints={'duration':1, 'pdays':-1,
                                                 'emp.var.rate':-1, 'nr.employed':-1})
xg_const.fit(X_train, y_train, eval_set=[(X_train, y_train),
                                        (X_test, y_test)], 
           verbose=100)
xg_const.score(X_test, y_test)
# Out:
# [0]	validation_0-aucpr:0.57070	validation_1-aucpr:0.58243
# [55]	validation_0-aucpr:0.77227	validation_1-aucpr:0.67339
# 0.9216276585413227

# %%
(pd.Series(xg_oob.feature_importances_, index=X_train.columns)
 .sort_values()
 .iloc[-10:]
 .plot.barh()
)
# Out:
# <AxesSubplot: >

# %%
(pd.Series(xg_step.feature_importances_, index=X_train.columns)
 .sort_values()
 .iloc[-10:]
 .plot.barh()
)
# Out:
# <AxesSubplot: >

# %%
(pd.Series(xg_const.feature_importances_, index=X_train.columns)
 .sort_values()
 .iloc[-10:]
 .plot.barh()
)
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## Summary
#
# - Explore your data
# - Tune your models
# - Understand your models
#
# Best! Matt Harrison (MetaSnake)
